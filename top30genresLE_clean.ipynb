# %%
import pandas as pd
import ast
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt

plt.style.use("seaborn")
SMALL_SIZE = 15
MEDIUM_SIZE = 18
BIGGER_SIZE = 21

plt.rc('font', size=SMALL_SIZE)  # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)  # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)  # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)  # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)  # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
dominating_genres = ["rock", "pop", "electronic", "metal", "alternativerock", "indierock"]

# %%
track_genres_df = pd.read_csv("feature_engineering/data/track_genres.csv", sep=";", header=None)
track_genres_df.columns = ["track_id", "genres"]
track_genres_df["genres"] = track_genres_df["genres"].apply(lambda r: ast.literal_eval(r))
track_genres_df["genres"] = track_genres_df["genres"].apply(lambda r: [g for g in r if g not in dominating_genres])
track_genres_df.set_index("track_id", inplace=True)
track_genres_df.head()
# Out:
#                                                      genres
# track_id
# 4868      [soul, singersongwriter, blues, jazz, pianoroc...
# 2900      [indiepop, shoegaze, dreampop, postpunk, elect...
# 572665               [soul, singersongwriter, blues, drama]
# 2897      [indiepop, postpunk, ambient, dreampop, shoega...
# 15100     [folk, indiefolk, banjo, folkrock, bluegrass, ...

# %%
len(track_genres_df)
# Out:
# 147156

# %%
events_df = pd.read_csv("feature_engineering/data/lowms_events_nondominating.csv", sep=";")[["user_id", "track_id"]]
events_df.head()
# Out:
#     user_id  track_id
# 0  31435741        53
# 1  31435741        53
# 2  31435741        53
# 3  31435741        53
# 4  31435741        53

# %%
events_with_genres_df = events_df.merge(track_genres_df, left_on="track_id", right_index=True)
events_with_genres_df.head()
# Out:
#     user_id  track_id                                             genres
# 0  31435741        53  [soul, poprock, poprock, rap, singersongwriter...
# 1  31435741        53  [soul, poprock, poprock, rap, singersongwriter...
# 2  31435741        53  [soul, poprock, poprock, rap, singersongwriter...
# 3  31435741        53  [soul, poprock, poprock, rap, singersongwriter...
# 4  31435741        53  [soul, poprock, poprock, rap, singersongwriter...

# %% [markdown]
# # for usergroups

# %%
classification_df = pd.read_csv("clustering/classification_clean.csv", sep=";", index_col="user_id")
classification_df.head()
# Out:
#           cluster
# user_id
# 10883488        1
# 35212267        3
# 38189090        3
# 22113634        3
# 3704198         3

# %%
genres_per_cluster_df = events_with_genres_df.merge(classification_df, left_on="user_id", right_index=True)[["genres", "cluster"]]
genres_per_cluster_df["genres"] = genres_per_cluster_df["genres"].apply(Counter)
genres_per_cluster_df = genres_per_cluster_df.groupby("cluster")["genres"].sum()
genres_per_cluster_df.head()
# Out:
# cluster
# 1    {'soul': 91367, 'poprock': 131041, 'rap': 1862...
# 2    {'soul': 134582, 'poprock': 330144, 'rap': 115...
# 3    {'postpunk': 8859, 'indiepop': 24682, 'experim...
# 4    {'soul': 55444, 'poprock': 74077, 'rap': 49874...
# Name: genres, dtype: object

# %%
sorted(genres_per_cluster_df.loc[4].items(), key=lambda t: t[1])[::-1]
# Out:
# [('experimental', 313467),
#  ('ambient', 249720),
#  ('electronica', 247655),
#  ('deathmetal', 237602),
#  ('hardrock', 208089),
#  ('progressivemetal', 200126),
#  ('hardcore', 194467),
#  ('triphop', 173374),
#  ('punk', 167509),
#  ('postrock', 167393),
#  ('electro', 162737),
#  ('downtempo', 153073),
#  ('progressiverock', 152423),
#  ('metalcore', 142238),
#  ('hiphop', 142235),
#  ('blackmetal', 138083),
#  ('industrial', 133577),
#  ('synthpop', 131294),
#  ('melodicdeathmetal', 125662),
#  ('postpunk', 122001),
#  ('thrashmetal', 120441),
#  ('indiepop', 119598),
#  ('classicrock', 113646),
#  ('singersongwriter', 105238),
#  ('folk', 104456),
#  ('electropop', 97564),
#  ('posthardcore', 95250),
#  ('alternativemetal', 92701),
#  ('emo', 89933),
#  ('doommetal', 87549),
#  ('numetal', 83329),
#  ('techno', 81044),
#  ('lounge', 80128),
#  ('newwave', 79704),
#  ('darkwave', 78253),
#  ('avantgarde', 78212),
#  ('gothicmetal', 74241),
#  ('poprock', 74077),
#  ('jazz', 73905),
#  ('technicaldeathmetal', 72912),
#  ('soundtrack', 72552),
#  ('easylistening', 71329),
#  ('trance', 66822),
#  ('powermetal', 66356),
#  ('lofi', 64447),
#  ('brutaldeathmetal', 63795),
#  ('grindcore', 63630),
#  ('house', 62801),
#  ('deathcore', 62417),
#  ('shoegaze', 61755),
#  ('dreampop', 59932),
#  ('nujazz', 59254),
#  ('noise', 58167),
#  ('psychedelicrock', 58151),
#  ('symphonicmetal', 57782),
#  ('grunge', 57384),
#  ('experimentalrock', 57374),
#  ('funk', 57225),
#  ('folkmetal', 56580),
#  ('britpop', 56149),
#  ('industrialmetal', 55683),
#  ('stonerrock', 55598),
#  ('soul', 55444),
#  ('gothicrock', 54338),
#  ('indietronica', 53993),
#  ('screamo', 53304),
#  ('speedmetal', 50058),
#  ('rap', 49874),
#  ('folkrock', 46980),
#  ('artrock', 45518),
#  ('ebm', 45095),
#  ('blues', 44883),
#  ('vikingmetal', 40573),
#  ('hardcorepunk', 39758),
#  ('bluesrock', 38008),
#  ('world', 36956),
#  ('mathcore', 36953),
#  ('garagerock', 36612),
#  ('industrialrock', 36409),
#  ('postmetal', 36003),
#  ('dubstep', 35216),
#  ('minimal', 34575),
#  ('darkambient', 34510),
#  ('newage', 34050),
#  ('poppunk', 32154),
#  ('noiserock', 31416),
#  ('groovemetal', 31134),
#  ('drumandbass', 30528),
#  ('softrock', 30455),
#  ('breakbeat', 29356),
#  ('dub', 28314),
#  ('acidjazz', 27689),
#  ('electroclash', 26750),
#  ('disco', 26740),
#  ('djent', 26106),
#  ('stonermetal', 25720),
#  ('swedishmetal', 25589),
#  ('melodichardcore', 25273),
#  ('melodicblackmetal', 25020),
#  ('finnishmetal', 24831),
#  ('electrohouse', 24817),
#  ('sleep', 24298),
#  ('classical', 23229),
#  ('glitch', 23227),
#  ('spacerock', 22464),
#  ('beats', 22263),
#  ('deathgrind', 22029),
#  ('mathrock', 21826),
#  ('bigbeat', 21284),
#  ('electroindustrial', 21030),
#  ('drone', 20927),
#  ('undergroundhiphop', 20905),
#  ('atmosphericblackmetal', 20501),
#  ('sludgemetal', 20189),
#  ('glamrock', 19792),
#  ('instrumentalrock', 19424),
#  ('jazzfusion', 19304),
#  ('futurepop', 19205),
#  ('avantgardemetal', 19146),
#  ('reggae', 18875),
#  ('indiefolk', 18873),
#  ('postgrunge', 18794),
#  ('dancepunk', 18740),
#  ('rockandroll', 18738),
#  ('neoclassical', 18177),
#  ('symphonicrock', 18162),
#  ('psychill', 18085),
#  ('neofolk', 17895),
#  ('symphonicblackmetal', 17866),
#  ('powerpop', 17688),
#  ('newrave', 17062),
#  ('noisepop', 16953),
#  ('electronicrock', 16162),
#  ('alternativehiphop', 16022),
#  ('norwegianblackmetal', 15675),
#  ('country', 15287),
#  ('breaks', 15060),
#  ('medieval', 14628),
#  ('alternativepop', 14536),
#  ('alternativedance', 14435),
#  ('ska', 14432),
#  ('dancepop', 14164),
#  ('modernrock', 13856),
#  ('progressivetrance', 13801),
#  ('celtic', 13731),
#  ('rb', 13588),
#  ('progressivehouse', 13313),
#  ('violin', 13243),
#  ('comedy', 13146),
#  ('technicalbrutaldeathmetal', 12571),
#  ('melodicmetalcore', 12448),
#  ('electropunk', 12387),
#  ('goregrind', 12278),
#  ('postblackmetal', 12264),
#  ('deephouse', 12051),
#  ('ambienttechno', 11749),
#  ('chillwave', 11647),
#  ('progressivedeathcore', 11523),
#  ('alternativepoprock', 11204),
#  ('abstract', 10637),
#  ('techhouse', 10537),
#  ('psychedelictrance', 10423),
#  ('freakfolk', 10245),
#  ('halloween', 10200),
#  ('brutaldeathcore', 10024),
#  ('dancerock', 9818),
#  ('horrorpunk', 9754),
#  ('latin', 9586),
#  ('jpop', 9553),
#  ('albumrock', 9523),
#  ('rockabilly', 9271),
#  ('southernrock', 9251),
#  ('chamberpop', 9170),
#  ('spokenword', 8885),
#  ('swedishdeathmetal', 8766),
#  ('glitchhop', 8725),
#  ('smoothjazz', 8623),
#  ('symphonicpowermetal', 8617),
#  ('straightedge', 8421),
#  ('breakcore', 8367),
#  ('depressiveblackmetal', 8312),
#  ('skapunk', 8259),
#  ('vocaltrance', 8096),
#  ('chiptune', 8076),
#  ('cyberpunk', 7989),
#  ('funkmetal', 7839),
#  ('chaotichardcore', 7762),
#  ('goatrance', 7701),
#  ('rapmetal', 7611),
#  ('poetry', 7591),
#  ('remix', 7528),
#  ('neosoul', 7474),
#  ('minimaltechno', 7470),
#  ('turntablism', 7402),
#  ('slayer', 7280),
#  ('jungle', 7243),
#  ('atmosphere', 7126),
#  ('norwegianmetal', 6944),
#  ('neoclassicalmetal', 6919),
#  ('experimentalpop', 6746),
#  ('germanmetal', 6735),
#  ('pianorock', 6729),
#  ('slowcore', 6709),
#  ('contemporaryclassical', 6643),
#  ('aggrotech', 6611),
#  ('melodicpowermetal', 6592),
#  ('gothenburgmetal', 6576),
#  ('skatepunk', 6571),
#  ('funkrock', 6459),
#  ('glammetal', 6450),
#  ('meditation', 6420),
#  ('rhythmandblues', 6363),
#  ('newweirdamerica', 6118),
#  ('christianrock', 6086),
#  ('garagepunk', 6031),
#  ('psychobilly', 6023),
#  ('instrumentalpostrock', 5992),
#  ('newromantic', 5782),
#  ('anime', 5779),
#  ('experimentalhiphop', 5750),
#  ('jazzfunk', 5738),
#  ('cello', 5714),
#  ('worldfusion', 5697),
#  ('c', 5602),
#  ('nwobhm', 5602),
#  ('abstracthiphop', 5557),
#  ('raprock', 5482),
#  ('protopunk', 5242),
#  ('crustpunk', 5225),
#  ('edm', 5207),
#  ('bossanova', 5168),
#  ('psychedelicfolk', 5166),
#  ('swing', 5159),
#  ('witchhouse', 5148),
#  ('artpop', 5018),
#  ('cabaret', 4993),
#  ('countryrock', 4795),
#  ('krautrock', 4768),
#  ('nudisco', 4753),
#  ('janglepop', 4615),
#  ('nowave', 4536),
#  ('thrashcore', 4451),
#  ('darkcabaret', 4412),
#  ('blackgaze', 4400),
#  ('contemporaryjazz', 4388),
#  ('opera', 4350),
#  ('wave', 4322),
#  ('rawblackmetal', 4198),
#  ('nintendocore', 4197),
#  ('liquidfunk', 4154),
#  ('suomirock', 4146),
#  ('jazzmetal', 4125),
#  ('bounce', 4099),
#  ('undergroundrap', 4076),
#  ('christmas', 4043),
#  ('jrock', 4040),
#  ('powernoise', 4024),
#  ('swedishblackmetal', 4014),
#  ('folkpunk', 3993),
#  ('grime', 3987),
#  ('christianmetal', 3909),
#  ('oldschoolhiphop', 3868),
#  ('cybermetal', 3844),
#  ('baroque', 3841),
#  ('quietstorm', 3833),
#  ('celticmetal', 3764),
#  ('paganblackmetal', 3729),
#  ('kpop', 3686),
#  ('polishdeathmetal', 3667),
#  ('reggaeton', 3634),
#  ('comedyrock', 3589),
#  ('tweepop', 3546),
#  ('chilllounge', 3483),
#  ('motown', 3451),
#  ('videogamemusic', 3420),
#  ('powerelectronics', 3418),
#  ('canadianmetal', 3327),
#  ('martialindustrial', 3304),
#  ('experimentaltechno', 3297),
#  ('vocaljazz', 3276),
#  ('electrojazz', 3271),
#  ('ukgarage', 3247),
#  ('steampunk', 3202),
#  ('visualkei', 3172),
#  ('futuregarage', 3148),
#  ('bells', 3143),
#  ('vocalhouse', 3139),
#  ('conscioushiphop', 3107),
#  ('crossoverthrash', 3102),
#  ('germanrock', 3039),
#  ('dancehall', 3023),
#  ('nyhc', 2978),
#  ('eurodance', 2936),
#  ('orchestra', 2926),
#  ('germanthrashmetal', 2901),
#  ('electroswing', 2877),
#  ('riotgrrrl', 2873),
#  ('brokenbeat', 2818),
#  ('lullaby', 2803),
#  ('experimentalambient', 2797),
#  ('floridadeathmetal', 2780),
#  ('banjo', 2764),
#  ('rootsreggae', 2739),
#  ('choral', 2714),
#  ('frenchmetal', 2680),
#  ('slamdeathmetal', 2661),
#  ('tango', 2656),
#  ('funkybreaks', 2583),
#  ('industrialtechno', 2553),
#  ('beatdown', 2545),
#  ('crunk', 2543),
#  ('postdisco', 2529),
#  ('folkpop', 2477),
#  ('neurofunk', 2467),
#  ('russianrock', 2456),
#  ('eastcoasthiphop', 2404),
#  ('industrialblackmetal', 2371),
#  ('upliftingtrance', 2353),
#  ('wonky', 2346),
#  ('jazzpiano', 2301),
#  ('darkstep', 2281),
#  ('polishmetal', 2258),
#  ('sleazerock', 2254),
#  ('trancecore', 2203),
#  ('fidgethouse', 2201),
#  ('acidhouse', 2155),
#  ('schlager', 2144),
#  ('discohouse', 2114),
#  ('chanson', 2010),
#  ('mashup', 2001),
#  ('frenchpop', 1983),
#  ('sunshinepop', 1973),
#  ('gospel', 1967),
#  ('progressivepsytrance', 1943),
#  ('jazzrap', 1934),
#  ('streetpunk', 1919),
#  ('cooljazz', 1913),
#  ('oi', 1903),
#  ('afrobeat', 1891),
#  ('hardcorehiphop', 1880),
#  ('britishinvasion', 1880),
#  ('progressivetechnicaldeathmetal', 1869),
#  ('freejazz', 1865),
#  ('westcoastrap', 1862),
#  ('europop', 1831),
#  ('accordion', 1827),
#  ('nordicfolk', 1809),
#  ('mpb', 1804),
#  ('digitalhardcore', 1794),
#  ('horrorcore', 1781),
#  ('dronemetal', 1757),
#  ('punkblues', 1743),
#  ('darkjazz', 1704),
#  ('drillandbass', 1702),
#  ('progressivebreaks', 1690),
#  ('contemporaryfolk', 1672),
#  ('canadianindie', 1647),
#  ('medievalfolk', 1645),
#  ('samba', 1634),
#  ('fullon', 1628),
#  ('scratch', 1600),
#  ('pornogrind', 1583),
#  ('jamband', 1583),
#  ('orientalmetal', 1582),
#  ('hardcoretechno', 1558),
#  ('anarchopunk', 1543),
#  ('funeraldoom', 1530),
#  ('hardtrance', 1524),
#  ('focus', 1517),
#  ('neopsychedelic', 1502),
#  ('powerviolence', 1479),
#  ('finnishdeathmetal', 1476),
#  ('bluegrass', 1434),
#  ('alternativecountry', 1432),
#  ('celticrock', 1432),
#  ('usbm', 1431),
#  ('pirate', 1425),
#  ('christianhardcore', 1420),
#  ('polishrock', 1398),
#  ('bassline', 1384),
#  ('jumpup', 1369),
#  ('electronicore', 1339),
#  ('easycore', 1322),
#  ('spaceambient', 1306),
#  ('polishblackmetal', 1303),
#  ('bellydance', 1300),
#  ('beachhouse', 1298),
#  ('erotica', 1288),
#  ('rockenespanol', 1258),
#  ('britishblues', 1229),
#  ('gothicsymphonicmetal', 1225),
#  ('salsa', 1214),
#  ('celticpunk', 1213),
#  ('teenpop', 1191),
#  ('flamenco', 1182),
#  ('bigband', 1181),
#  ('football', 1152),
#  ('eurovision', 1147),
#  ('indiepunk', 1143),
#  ('gothicdoom', 1128),
#  ('sitar', 1116),
#  ('bebop', 1112),
#  ('happyhardcore', 1111),
#  ('germanmetalcore', 1110),
#  ('midwestemo', 1108),
#  ('outsider', 1108),
#  ('cartoon', 1098),
#  ('madchester', 1085),
#  ('brazilianmetal', 1070),
#  ('spanishrock', 1053),
#  ('jazzguitar', 1046),
#  ('antifolk', 1042),
#  ('environmental', 1037),
#  ('rocknacional', 1017),
#  ('irishfolk', 1005),
#  ('outlawcountry', 996),
#  ('rocksteady', 993),
#  ('souljazz', 984),
#  ('latinrock', 965),
#  ('microhouse', 961),
#  ('medievalrock', 950),
#  ('nerdcore', 948),
#  ('bboy', 940),
#  ('geekrock', 922),
#  ('latinpop', 916),
#  ('smoothsoul', 915),
#  ('drama', 914),
#  ('finnishblackmetal', 889),
#  ('chillstep', 876),
#  ('latinjazz', 869),
#  ('deepambient', 868),
#  ('beachmusic', 860),
#  ('germanhiphop', 846),
#  ('polishjazz', 838),
#  ('tribute', 828),
#  ('acappella', 827),
#  ('minimalwave', 823),
#  ('ukhiphop', 821),
#  ('healing', 816),
#  ('boyband', 815),
#  ('classicsoul', 811),
#  ('noisepunk', 811),
#  ('filthstep', 806),
#  ('brostep', 802),
#  ('dubtechno', 801),
#  ('gypsypunk', 793),
#  ('experimentalelectronic', 790),
#  ('wrestling', 788),
#  ('harp', 787),
#  ('disney', 786),
#  ('electricblues', 778),
#  ('bagpipe', 774),
#  ('blackthrash', 767),
#  ('brazilianrock', 761),
#  ('rootsrock', 761),
#  ('klezmer', 760),
#  ('harpsichord', 747),
#  ('girlgroup', 724),
#  ('russianalternative', 719),
#  ('acidtechno', 717),
#  ('doowop', 716),
#  ('swissmetal', 715),
#  ('polka', 713),
#  ('ninja', 709),
#  ('metallichardcore', 709),
#  ('boombap', 705),
#  ('classicalpiano', 701),
#  ('instrumentalprogressivemetal', 697),
#  ('karaoke', 675),
#  ('scottishmetal', 674),
#  ('freestyle', 674),
#  ('melancholia', 674),
#  ('etherealwave', 670),
#  ('ambientidm', 670),
#  ('motivation', 668),
#  ('balearic', 667),
#  ('emopunk', 665),
#  ('hardstyle', 662),
#  ('irishrock', 661),
#  ('danishmetal', 659),
#  ('theme', 649),
#  ('mantra', 648),
#  ('newjackswing', 643),
#  ('poprap', 639),
#  ('hardbop', 638),
#  ('speedcore', 636),
#  ('swedishpop', 632),
#  ('detroittechno', 631),
#  ('screamocore', 628),
#  ('nugaze', 624),
#  ('deltablues', 610),
#  ('hollywood', 601),
#  ('cowpunk', 586),
#  ('reading', 578),
#  ('italianmetal', 575),
#  ('avantgardejazz', 575),
#  ('bubblegumpop', 574),
#  ('neotango', 569),
#  ('progressiveposthardcore', 566),
#  ('russianmetal', 563),
#  ('chillgroove', 558),
#  ('ukfunky', 553),
#  ('tropical', 553),
#  ('spanishpop', 546),
#  ('nativeamerican', 544),
#  ('heartlandrock', 537),
#  ('filterhouse', 536),
#  ('neoprogressive', 535),
#  ('dungeonsynth', 529),
#  ('melodichardrock', 528),
#  ('reggaerock', 517),
#  ('reggaefusion', 513),
#  ('worship', 510),
#  ('instrumentaldeathmetal', 509),
#  ('electrodub', 503),
#  ('britishfolk', 496),
#  ('renaissance', 483),
#  ('newbeat', 478),
#  ('bostonhardcore', 470),
#  ('fingerstyle', 467),
#  ('jazzsaxophone', 464),
#  ('intelligentdancemusic', 462),
#  ('ukpop', 456),
#  ('gfunk', 450),
#  ('blackenedcrust', 447),
#  ('ambientfolk', 439),
#  ('fake', 437),
#  ('latinalternative', 436),
#  ('afropop', 435),
#  ('alternativehardcore', 432),
#  ('electrotrash', 432),
#  ('nuskoolbreaks', 429),
#  ('throatsinging', 422),
#  ('thrashgroovemetal', 421),
#  ('ambientindustrial', 418),
#  ('ccm', 415),
#  ('yachtrock', 410),
#  ('hardhouse', 406),
#  ('ukulele', 406),
#  ('dutchmetal', 405),
#  ('cumbia', 404),
#  ('hinrg', 403),
#  ('retroelectro', 395),
#  ('loversrock', 394),
#  ('germanblackmetal', 393),
#  ('popfolk', 391),
#  ('frenchrock', 388),
#  ('frenchblackmetal', 382),
#  ('stcenturyclassical', 376),
#  ('hauntology', 371),
#  ('neuedeutschewelle', 365),
#  ('liedermacher', 358),
#  ('rumba', 355),
#  ('chicagoblues', 352),
#  ('hardalternative', 351),
#  ('demoscene', 349),
#  ('afrikaans', 349),
#  ('canadianrock', 348),
#  ('doomcore', 346),
#  ('latinmetal', 336),
#  ('musicbox', 332),
#  ('theremin', 326),
#  ('moog', 320),
#  ('pfunk', 318),
#  ('jazzblues', 317),
#  ('bhangra', 317),
#  ('neometal', 314),
#  ('exotica', 312),
#  ('deepchill', 312),
#  ('christianhardrock', 311),
#  ('surfmusic', 304),
#  ('countrypop', 304),
#  ('australianmetal', 303),
#  ('mambo', 300),
#  ('chicagohouse', 298),
#  ('vocaloid', 296),
#  ('didgeridoo', 296),
#  ('nuelectro', 292),
#  ('garagepop', 289),
#  ('greekblackmetal', 288),
#  ('jumpstyle', 285),
#  ('ghettotech', 281),
#  ('germanindie', 281),
#  ('japanoise', 281),
#  ('classicalguitar', 272),
#  ('jazztrumpet', 271),
#  ('cantautor', 270),
#  ('australianrock', 266),
#  ('miamibass', 265),
#  ('tribalhouse', 264),
#  ('polishpunk', 262),
#  ('hardtechno', 261),
#  ('psychedelicdoom', 256),
#  ('ukrainianblackmetal', 255),
#  ('hurdygurdy', 251),
#  ('greekmetal', 250),
#  ('oldschoolthrash', 247),
#  ('southernhiphop', 245),
#  ('bassmusic', 244),
#  ('chillbeats', 244),
#  ('drumfunk', 243),
#  ('traditionalcountry', 242),
#  ('irishmetal', 239),
#  ('sufi', 238),
#  ('jmetal', 236),
#  ('capoeira', 235),
#  ('countryblues', 234),
#  ('northernsoul', 234),
#  ('hamburgerschule', 230),
#  ('germanreggae', 229),
#  ('handsup', 227),
#  ('idol', 227),
#  ('acousticblues', 226),
#  ('italianpop', 226),
#  ('hungarianmetal', 225),
#  ('vikingfolk', 222),
#  ('neopagan', 222),
#  ('calypso', 212),
#  ('neuedeutschetodeskunst', 212),
#  ('christianmusic', 208),
#  ('darktechno', 202),
#  ('austropop', 201),
#  ('showtunes', 200),
#  ('polishfolk', 200),
#  ('chillouttrance', 197),
#  ('jazztrio', 194),
#  ('technicalblackmetal', 192),
#  ('russianhiphop', 191),
#  ('koreanpop', 191),
#  ('drift', 188),
#  ('soundart', 186),
#  ('raregroove', 184),
#  ('minimaltechhouse', 182),
#  ('modernblues', 181),
#  ('praise', 180),
#  ('gogo', 177),
#  ('accordeon', 177),
#  ('italianprogressiverock', 174),
#  ('austrianmetal', 173),
#  ('rai', 171),
#  ('spanishindiepop', 169),
#  ('norwegiandeathmetal', 164),
#  ('texasblues', 163),
#  ('funkcarioca', 163),
#  ('gypsyjazz', 161),
#  ('tone', 161),
#  ('redneck', 159),
#  ('ringtone', 158),
#  ('abstractbeats', 158),
#  ('deepfunk', 157),
#  ('complextro', 156),
#  ('scifimetal', 154),
#  ('animerock', 153),
#  ('crackrocksteady', 150),
#  ('terrorcore', 150),
#  ('arabesk', 150),
#  ('darkhardcore', 150),
#  ('mariachi', 148),
#  ('futurerock', 147),
#  ('cajun', 140),
#  ('minimaldub', 137),
#  ('indieemo', 137),
#  ('germanpop', 135),
#  ('bolero', 134),
#  ('shamanic', 133),
#  ('finnishfolk', 132),
#  ('trova', 131),
#  ('vaudeville', 131),
#  ('canterburyscene', 130),
#  ('gothicamericana', 129),
#  ('highlife', 128),
#  ('christiandeathcore', 127),
#  ('hippop', 127),
#  ('blackdeath', 125),
#  ('shanty', 125),
#  ('melodicprogressivemetal', 124),
#  ('norwegianfolk', 124),
#  ('gangsterrap', 123),
#  ('fado', 123),
#  ('soncubano', 123),
#  ('soulblues', 122),
#  ('ragtime', 122),
#  ('eurobeat', 122),
#  ('pubrock', 121),
#  ('punkska', 121),
#  ('frenchhiphop', 120),
#  ('moombahton', 119),
#  ('yeye', 119),
#  ('dreamgaze', 118),
#  ('hawaiian', 118),
#  ('ukhc', 117),
#  ('phillysoul', 116),
#  ('dixieland', 114),
#  ('crossoverprog', 113),
#  ('middleearth', 112),
#  ('asmr', 111),
#  ('russianpop', 111),
#  ('portuguesemetal', 110),
#  ('britishsoul', 110),
#  ('recorder', 110),
#  ('earlymusic', 109),
#  ('northernirishindie', 106),
#  ('mathpop', 106),
#  ('hiphouse', 106),
#  ('southernsoul', 106),
#  ('neuedeutscheharte', 105),
#  ('slampoetry', 104),
#  ('swedishpunk', 102),
#  ('neorockabilly', 101),
#  ('sega', 100),
#  ('futurefunk', 100),
#  ('magyar', 97),
#  ('jpunk', 96),
#  ('musiqueconcrete', 95),
#  ('bostonpunk', 94),
#  ('gabba', 94),
#  ('turkishrock', 90),
#  ('germanpunk', 90),
#  ('spaceagepop', 90),
#  ('speedgarage', 89),
#  ('belgianrock', 87),
#  ('kora', 87),
#  ('lightmusic', 86),
#  ('newagepiano', 85),
#  ('polishreggae', 85),
#  ('acousticpop', 85),
#  ('raggajungle', 84),
#  ('pianoblues', 84),
#  ('latinhiphop', 83),
#  ('oud', 83),
#  ('russianpunk', 82),
#  ('spanishmetal', 82),
#  ('boogiewoogie', 82),
#  ('nwothm', 81),
#  ('shibuyakei', 80),
#  ('nederpop', 80),
#  ('chillhop', 79),
#  ('ballroom', 78),
#  ('benga', 78),
#  ('rockgaucho', 75),
#  ('merengue', 75),
#  ('indiepoprock', 74),
#  ('orgcore', 74),
#  ('marchingband', 73),
#  ('norwegianrock', 72),
#  ('experimentaldubstep', 70),
#  ('slavicmetal', 69),
#  ('irishpop', 69),
#  ('balkanbrass', 69),
#  ('memphissoul', 69),
#  ('swedishhardcore', 68),
#  ('stringquartet', 67),
#  ('footwork', 67),
#  ('kuduro', 67),
#  ('freefolk', 66),
#  ('choro', 65),
#  ('acousticpunk', 65),
#  ('slavicfolkmetal', 64),
#  ('bedroompop', 64),
#  ('zydeco', 64),
#  ('bubblegumdance', 63),
#  ('britishblackmetal', 63),
#  ('volksmusik', 63),
#  ('carnaval', 61),
#  ('harmonicablues', 61),
#  ('punjabi', 60),
#  ('movietunes', 59),
#  ('broadway', 59),
#  ('christianpop', 58),
#  ('modernhardrock', 58),
#  ('polyphony', 58),
#  ('desi', 55),
#  ('classicrussianrock', 54),
#  ('polishhiphop', 54),
#  ('retrometal', 53),
#  ('instrumentalfunk', 53),
#  ('skajazz', 53),
#  ('southerngospel', 53),
#  ('skinheadreggae', 53),
#  ('icelandicmetal', 52),
#  ('australianhardcore', 52),
#  ('italodance', 52),
#  ('childrensmusic', 52),
#  ('swedishhiphop', 51),
#  ('ukrainianrock', 51),
#  ('boogaloo', 50),
#  ('indieelectropop', 50),
#  ('kirtan', 49),
#  ('frenchjazz', 49),
#  ('deepprogressivehouse', 49),
#  ('organicambient', 49),
#  ('dutchrock', 48),
#  ('tibetan', 47),
#  ('germanpoprock', 46),
#  ('canadianblackmetal', 46),
#  ('romantico', 46),
#  ('brassband', 46),
#  ('lilith', 44),
#  ('rapconscient', 43),
#  ('doujin', 43),
#  ('modrevival', 42),
#  ('darkpsytrance', 42),
#  ('soukous', 42),
#  ('novampb', 41),
#  ('trapmusic', 41),
#  ('traditionalska', 41),
#  ('popnacional', 40),
#  ('britishjazz', 40),
#  ('tecnobrega', 40),
#  ('desertblues', 40),
#  ('freakbeat', 40),
#  ('grungepop', 40),
#  ('folkmusik', 39),
#  ('flamencoguitar', 39),
#  ('brazilianpsychedelic', 39),
#  ('riodelaplata', 38),
#  ('discofox', 38),
#  ('progressiveelectrohouse', 37),
#  ('westernswing', 37),
#  ('minecraft', 36),
#  ('finnishhiphop', 36),
#  ('frenchfolk', 36),
#  ('germanjazz', 36),
#  ('scottishrock', 35),
#  ('neworleansjazz', 35),
#  ('modernbluesrock', 35),
#  ('duduk', 35),
#  ('israelimetal', 34),
#  ('norwegianjazz', 34),
#  ('pagode', 34),
#  ('nycrap', 34),
#  ('forro', 33),
#  ('mexicanrock', 33),
#  ('jumpblues', 33),
#  ('oldtime', 33),
#  ('loungehouse', 33),
#  ('estonianpop', 32),
#  ('finnishreggae', 32),
#  ('brazilianexperimental', 32),
#  ('acididm', 32),
#  ('minimaldubstep', 32),
#  ('drill', 32),
#  ('spanishhiphop', 32),
#  ('contemporarycountry', 32),
#  ('israelirock', 32),
#  ('brazilianindie', 31),
#  ('swedishhardrock', 31),
#  ('indianclassical', 31),
#  ('countrygospel', 31),
#  ('bachata', 31),
#  ('neworleansfunk', 31),
#  ('australianindie', 31),
#  ('britishindierock', 30),
#  ('emorap', 30),
#  ('skarevival', 30),
#  ('indiejazz', 30),
#  ('jazzdrums', 30),
#  ('tekno', 30),
#  ('fallenangel', 29),
#  ('ranchera', 29),
#  ('swedishreggae', 29),
#  ('steelguitar', 29),
#  ('darkblackmetal', 28),
#  ('turkishpop', 28),
#  ('popchileno', 28),
#  ('vogue', 28),
#  ('fussball', 27),
#  ('iskelma', 27),
#  ('detroithiphop', 26),
#  ('deeptechhouse', 26),
#  ('russianfolk', 26),
#  ('spanishpunk', 26),
#  ('ukhouse', 26),
#  ('fastmelodicpunk', 25),
#  ('forestpsy', 24),
#  ('chiphop', 24),
#  ('russianindie', 24),
#  ('worldchill', 23),
#  ('canadianfolk', 22),
#  ('andean', 22),
#  ('finnishpop', 22),
#  ('germanindierock', 22),
#  ('swedishindiepop', 22),
#  ('latvianrock', 22),
#  ('ethiojazz', 22),
#  ('texascountry', 22),
#  ('deepvocalhouse', 21),
#  ('polishmodernjazz', 21),
#  ('ostrock', 21),
#  ('latinska', 21),
#  ('tarantella', 21),
#  ('germanpunkrock', 21),
#  ('gamelan', 21),
#  ('contemporarygospel', 20),
#  ('jazzorgan', 20),
#  ('laboratorio', 20),
#  ('italianfolk', 20),
#  ('brazilianthrashmetal', 19),
#  ('spanishpoprock', 19),
#  ('riddim', 19),
#  ('italianblackmetal', 19),
#  ('villancicos', 19),
#  ('hardcorebreaks', 19),
#  ('welshrock', 19),
#  ('dutchjazz', 19),
#  ('scottishindie', 19),
#  ('dronefolk', 19),
#  ('germanelectronica', 18),
#  ('bayareaindie', 18),
#  ('newamericana', 18),
#  ('viola', 17),
#  ('soundeffects', 17),
#  ('deepdnb', 17),
#  ('talentshow', 17),
#  ('experimentalhouse', 17),
#  ('brega', 16),
#  ('zeuhl', 16),
#  ('frenchpunk', 16),
#  ('brillbuildingpop', 16),
#  ('trashrock', 15),
#  ('brazilianblackmetal', 15),
#  ('dinnerjazz', 15),
#  ('belgianblackmetal', 15),
#  ('christianpunk', 15),
#  ('electrolatino', 15),
#  ('deepprogressivetrance', 15),
#  ('gravewave', 15),
#  ('traditionalfolk', 15),
#  ('popromantico', 15),
#  ('germanhardcore', 15),
#  ('canadianhiphop', 15),
#  ('garagepsych', 15),
#  ('soca', 15),
#  ('timba', 14),
#  ('organicelectronic', 14),
#  ('serialism', 14),
#  ('chileanindie', 14),
#  ('britishcomedy', 14),
#  ('phillyrap', 13),
#  ('christianhiphop', 13),
#  ('maghreb', 13),
#  ('latinfunk', 13),
#  ('duranguense', 13),
#  ('corrosion', 13),
#  ('swedishjazz', 13),
#  ('wrock', 13),
#  ('germandance', 13),
#  ('quebecdeathmetal', 12),
#  ('tejano', 12),
#  ('mizrahi', 12),
#  ('nasheed', 12),
#  ('cymraeg', 12),
#  ('postscreamo', 12),
#  ('hiphoptuga', 12),
#  ('liturgical', 12),
#  ('newwavepop', 12),
#  ('gospelblues', 11),
#  ('danishpop', 11),
#  ('chicanorap', 11),
#  ('ghazal', 11),
#  ('mexicanpop', 11),
#  ('retrosoul', 10),
#  ('freeimprovisation', 10),
#  ('scottishindierock', 10),
#  ('geekfolk', 10),
#  ('nuevacancion', 9),
#  ('darkminimaltechno', 9),
#  ('comic', 9),
#  ('rumbacatalana', 9),
#  ('hyphy', 9),
#  ('spanishreggae', 9),
#  ('progressivebluegrass', 9),
#  ('countryroad', 9),
#  ('chinesepipa', 9),
#  ('russianblackmetal', 8),
#  ('hammereddulcimer', 8),
#  ('bemani', 8),
#  ('italianopera', 8),
#  ('danishindie', 8),
#  ('italianjazz', 8),
#  ('neworleansblues', 8),
#  ('pony', 8),
#  ('vallenato', 8),
#  ('christianalternativerock', 8),
#  ('norwegianhiphop', 8),
#  ('kiwirock', 7),
#  ('dunedinsound', 7),
#  ('catstep', 7),
#  ('russianreggae', 7),
#  ('psychedelicbluesrock', 7),
#  ('manguebit', 7),
#  ('merseybeat', 7),
#  ('jazzvibraphone', 7),
#  ('hoerspiel', 7),
#  ('progressivealternative', 7),
#  ('pixie', 7),
#  ('cpop', 6),
#  ('jindie', 6),
#  ('battlerap', 6),
#  ('polishelectronica', 6),
#  ...]

# %%
n_events_df = events_df.merge(classification_df, left_on="user_id", right_index=True).groupby("cluster").size()
n_events_df
# Out:
# cluster
# 1     783090
# 2    2094082
# 3     186921
# 4    1618048
# dtype: int64

# %%
# %matplotlib qt
c = 1
for count in genres_per_cluster_df.values:
    sorted_occs = sorted(dict(count).items(), key=lambda tup: tup[1])[::-1][:30]
    ys = list(zip(*sorted_occs))[1]
    ys = np.array(ys) / n_events_df.loc[c]
    plt.plot(list(range(30)), ys, "-o", label=r"$U_{C_" + str(c) + "}$")
    c += 1
plt.legend()
plt.ylabel("relative genre importance")
plt.xlabel("Top 30 genres")
plt.grid(False)
plt.show()

# %%
gradients = []
c = 1
for count in genres_per_cluster_df.values:
    sorted_occs = sorted(dict(count).items(), key=lambda tup: tup[1])[::-1][:10]
    ys = list(zip(*sorted_occs))[1]
    ys = np.array(ys) / n_events_df.loc[c]
    gradients.append(np.mean(np.gradient(ys)))
    c += 1

# %%
gradients
# Out:
# [-0.03545294921401117,
#  -0.01207357209507555,
#  -0.04215497456144574,
#  -0.011001249653903962]

# %% [markdown]
# # for track cluster

# %%
track_classification_df = pd.read_csv("clustering/track_to_cluster.csv", sep=";").set_index("track_id")
track_classification_df = track_classification_df[track_classification_df["cluster"] != -1]
track_classification_df["cluster"] += 1
track_classification_df.head()
# Out:
#           cluster
# track_id
# 53              2
# 127             2
# 182             2
# 219             2
# 289             2

# %%
track_classification_df["cluster"].unique()
# Out:
# array([2, 4, 1, 3], dtype=int64)

# %%
genres_per_cluster_df = events_with_genres_df.merge(track_classification_df, left_on="track_id", right_index=True)[["genres", "cluster"]]
genres_per_cluster_df["genres"] = genres_per_cluster_df["genres"].apply(Counter)
genres_per_cluster_df = genres_per_cluster_df.groupby("cluster")["genres"].sum()
genres_per_cluster_df.head()
# Out:
# cluster
# 1    {'synthpop': 8211, 'newwave': 9237, 'electro':...
# 2    {'soul': 206755, 'poprock': 463608, 'rap': 170...
# 3    {'progressiverock': 14460, 'experimental': 561...
# 4    {'bluesrock': 12383, 'blues': 13823, 'garagero...
# Name: genres, dtype: object

# %%
sorted(genres_per_cluster_df.loc[4].items(), key=lambda t: t[1])[::-1]
# Out:
# [('experimental', 159261),
#  ('electronica', 152556),
#  ('ambient', 133745),
#  ('deathmetal', 117630),
#  ('postrock', 110616),
#  ('electro', 106561),
#  ('triphop', 102768),
#  ('downtempo', 86755),
#  ('progressivemetal', 86385),
#  ('hardrock', 80644),
#  ('hardcore', 77933),
#  ('blackmetal', 70682),
#  ('industrial', 69987),
#  ('progressiverock', 69557),
#  ('postpunk', 68073),
#  ('punk', 67945),
#  ('synthpop', 65585),
#  ('techno', 61147),
#  ('indiepop', 59399),
#  ('metalcore', 59063),
#  ('melodicdeathmetal', 58228),
#  ('electropop', 50651),
#  ('trance', 49517),
#  ('lounge', 48932),
#  ('thrashmetal', 47104),
#  ('house', 46883),
#  ('shoegaze', 44083),
#  ('hiphop', 41663),
#  ('doommetal', 39688),
#  ('classicrock', 38356),
#  ('brutaldeathmetal', 38264),
#  ('newwave', 38229),
#  ('posthardcore', 37767),
#  ('nujazz', 36670),
#  ('avantgarde', 36470),
#  ('alternativemetal', 35360),
#  ('grindcore', 35063),
#  ('technicaldeathmetal', 34950),
#  ('noise', 34753),
#  ('darkwave', 34226),
#  ('deathcore', 33981),
#  ('emo', 33814),
#  ('jazz', 33787),
#  ('soundtrack', 32613),
#  ('dreampop', 31855),
#  ('lofi', 31741),
#  ('funk', 30873),
#  ('britpop', 30443),
#  ('indietronica', 29785),
#  ('experimentalrock', 29616),
#  ('folk', 27466),
#  ('easylistening', 26623),
#  ('stonerrock', 26540),
#  ('numetal', 26296),
#  ('psychedelicrock', 26196),
#  ('gothicmetal', 26187),
#  ('industrialmetal', 26126),
#  ('grunge', 25707),
#  ('powermetal', 25454),
#  ('postmetal', 25444),
#  ('drumandbass', 24915),
#  ('ebm', 24551),
#  ('symphonicmetal', 24253),
#  ('breakbeat', 23319),
#  ('dubstep', 23293),
#  ('folkmetal', 22960),
#  ('poprock', 22426),
#  ('artrock', 22389),
#  ('singersongwriter', 21439),
#  ('gothicrock', 21393),
#  ('electrohouse', 20891),
#  ('dub', 20617),
#  ('vikingmetal', 20534),
#  ('speedmetal', 19592),
#  ('minimal', 19571),
#  ('noiserock', 19122),
#  ('industrialrock', 18830),
#  ('garagerock', 18627),
#  ('instrumentalrock', 18512),
#  ('screamo', 17785),
#  ('bigbeat', 17529),
#  ('acidjazz', 17017),
#  ('mathcore', 16974),
#  ('glitch', 15453),
#  ('world', 15405),
#  ('newage', 15225),
#  ('spacerock', 15016),
#  ('stonermetal', 14833),
#  ('hardcorepunk', 14613),
#  ('mathrock', 14584),
#  ('psychill', 14534),
#  ('disco', 14349),
#  ('beats', 14052),
#  ('finnishmetal', 13969),
#  ('blues', 13823),
#  ('electroclash', 13725),
#  ('progressivetrance', 13678),
#  ('soul', 13665),
#  ('darkambient', 13573),
#  ('melodicblackmetal', 13226),
#  ('djent', 13037),
#  ('sludgemetal', 12584),
#  ('bluesrock', 12383),
#  ('breaks', 12242),
#  ('swedishmetal', 12228),
#  ('electroindustrial', 12098),
#  ('deathgrind', 11964),
#  ('noisepop', 11765),
#  ('progressivehouse', 11642),
#  ('atmosphericblackmetal', 11375),
#  ('jazzfusion', 11043),
#  ('classical', 10933),
#  ('newrave', 10559),
#  ('techhouse', 10351),
#  ('avantgardemetal', 9824),
#  ('dancepunk', 9764),
#  ('rap', 9722),
#  ('drone', 9708),
#  ('electronicrock', 9446),
#  ('sleep', 9361),
#  ('deephouse', 9283),
#  ('psychedelictrance', 9268),
#  ('glamrock', 9209),
#  ('symphonicblackmetal', 8765),
#  ('norwegianblackmetal', 8735),
#  ('ambienttechno', 8646),
#  ('chillwave', 8406),
#  ('rockandroll', 8228),
#  ('futurepop', 7846),
#  ('groovemetal', 7838),
#  ('folkrock', 7666),
#  ('powerpop', 7382),
#  ('goatrance', 7363),
#  ('alternativedance', 7232),
#  ('minimaltechno', 7173),
#  ('neoclassical', 7145),
#  ('melodichardcore', 7025),
#  ('electropunk', 6931),
#  ('reggae', 6750),
#  ('jungle', 6726),
#  ('violin', 6495),
#  ('postblackmetal', 6449),
#  ('goregrind', 6391),
#  ('symphonicrock', 6162),
#  ('technicalbrutaldeathmetal', 6070),
#  ('postgrunge', 6066),
#  ('chiptune', 6050),
#  ('dancerock', 5879),
#  ('jpop', 5797),
#  ('breakcore', 5684),
#  ('glitchhop', 5647),
#  ('vocaltrance', 5618),
#  ('dancepop', 5578),
#  ('brutaldeathcore', 5478),
#  ('modernrock', 5439),
#  ('abstract', 5436),
#  ('neofolk', 5416),
#  ('alternativepoprock', 5335),
#  ('poppunk', 5253),
#  ('instrumentalpostrock', 5210),
#  ('alternativepop', 5193),
#  ('cyberpunk', 5184),
#  ('neoclassicalmetal', 5127),
#  ('softrock', 5070),
#  ('turntablism', 4996),
#  ('jazzfunk', 4958),
#  ('comedy', 4754),
#  ('depressiveblackmetal', 4654),
#  ('remix', 4580),
#  ('edm', 4416),
#  ('liquidfunk', 4413),
#  ('halloween', 4352),
#  ('aggrotech', 4105),
#  ('ska', 4089),
#  ('swedishdeathmetal', 4080),
#  ('celtic', 4046),
#  ('rockabilly', 3951),
#  ('norwegianmetal', 3888),
#  ('glammetal', 3859),
#  ('indiefolk', 3792),
#  ('witchhouse', 3744),
#  ('smoothjazz', 3743),
#  ('chamberpop', 3693),
#  ('melodicmetalcore', 3654),
#  ('progressivedeathcore', 3639),
#  ('undergroundhiphop', 3626),
#  ('gothenburgmetal', 3613),
#  ('horrorpunk', 3608),
#  ('anime', 3604),
#  ('nudisco', 3558),
#  ('meditation', 3519),
#  ('funkmetal', 3510),
#  ('country', 3353),
#  ('straightedge', 3344),
#  ('worldfusion', 3315),
#  ('bounce', 3289),
#  ('latin', 3229),
#  ('chaotichardcore', 3175),
#  ('crustpunk', 3055),
#  ('medieval', 3047),
#  ('krautrock', 3001),
#  ('psychobilly', 2977),
#  ('blackgaze', 2971),
#  ('cello', 2965),
#  ('atmosphere', 2918),
#  ('slowcore', 2738),
#  ('alternativehiphop', 2723),
#  ('spokenword', 2705),
#  ('swedishblackmetal', 2679),
#  ('powerelectronics', 2678),
#  ('albumrock', 2676),
#  ('suomirock', 2672),
#  ('powernoise', 2620),
#  ('contemporaryjazz', 2610),
#  ('germanmetal', 2609),
#  ('c', 2560),
#  ('melodicpowermetal', 2502),
#  ('funkrock', 2490),
#  ('christianmetal', 2418),
#  ('janglepop', 2416),
#  ('abstracthiphop', 2413),
#  ('opera', 2384),
#  ('neurofunk', 2377),
#  ('rawblackmetal', 2370),
#  ('experimentalpop', 2361),
#  ('polishdeathmetal', 2337),
#  ('vocalhouse', 2332),
#  ('nowave', 2324),
#  ('acidhouse', 2284),
#  ('pianorock', 2279),
#  ('discohouse', 2263),
#  ('upliftingtrance', 2213),
#  ('funkybreaks', 2184),
#  ('brokenbeat', 2181),
#  ('paganblackmetal', 2179),
#  ('futuregarage', 2171),
#  ('tweepop', 2171),
#  ('southernrock', 2158),
#  ('experimentaltechno', 2154),
#  ('chilllounge', 2125),
#  ('ukgarage', 2122),
#  ('postdisco', 2095),
#  ('rb', 2087),
#  ('kpop', 2087),
#  ('darkstep', 2066),
#  ('electrojazz', 2054),
#  ('sleazerock', 2024),
#  ('symphonicpowermetal', 2023),
#  ('eurodance', 1971),
#  ('jrock', 1952),
#  ('canadianmetal', 1927),
#  ('grime', 1923),
#  ('visualkei', 1907),
#  ('jazzmetal', 1871),
#  ('skapunk', 1867),
#  ('fullon', 1840),
#  ('reggaeton', 1834),
#  ('garagepunk', 1799),
#  ('slayer', 1741),
#  ('progressivepsytrance', 1740),
#  ('rapmetal', 1701),
#  ('bossanova', 1699),
#  ('artpop', 1667),
#  ('christianrock', 1662),
#  ('riotgrrrl', 1590),
#  ('progressivebreaks', 1590),
#  ('fidgethouse', 1582),
#  ('baroque', 1567),
#  ('drillandbass', 1536),
#  ('cybermetal', 1532),
#  ('poetry', 1525),
#  ('hardtrance', 1522),
#  ('protopunk', 1505),
#  ('industrialblackmetal', 1503),
#  ('orchestra', 1499),
#  ('neosoul', 1491),
#  ('newromantic', 1422),
#  ('bassline', 1421),
#  ('martialindustrial', 1419),
#  ('wave', 1398),
#  ('polishmetal', 1383),
#  ('bells', 1375),
#  ('germanthrashmetal', 1374),
#  ('pornogrind', 1373),
#  ('freakfolk', 1364),
#  ('tango', 1344),
#  ('germanrock', 1340),
#  ('nintendocore', 1340),
#  ('lullaby', 1300),
#  ('industrialtechno', 1292),
#  ('choral', 1271),
#  ('crossoverthrash', 1263),
#  ('christianhardcore', 1257),
#  ('electroswing', 1257),
#  ('swing', 1250),
#  ('finnishdeathmetal', 1225),
#  ('bellydance', 1196),
#  ('floridadeathmetal', 1185),
#  ('skatepunk', 1178),
#  ('neopsychedelic', 1166),
#  ('wonky', 1162),
#  ('progressivetechnicaldeathmetal', 1148),
#  ('thrashcore', 1146),
#  ('erotica', 1133),
#  ('quietstorm', 1106),
#  ('newweirdamerica', 1100),
#  ('crunk', 1098),
#  ('digitalhardcore', 1089),
#  ('steampunk', 1076),
#  ('jumpup', 1072),
#  ('videogamemusic', 1069),
#  ('frenchpop', 1068),
#  ('slamdeathmetal', 1056),
#  ('jazzpiano', 1031),
#  ('jamband', 1028),
#  ('microhouse', 1028),
#  ('rhythmandblues', 1016),
#  ('contemporaryclassical', 991),
#  ('europop', 952),
#  ('darkcabaret', 923),
#  ('madchester', 918),
#  ('usbm', 914),
#  ('souljazz', 911),
#  ('nwobhm', 875),
#  ('schlager', 873),
#  ('oi', 872),
#  ('scratch', 872),
#  ('freejazz', 862),
#  ('undergroundrap', 860),
#  ('experimentalhiphop', 857),
#  ('christmas', 854),
#  ('instrumentalprogressivemetal', 848),
#  ('celticmetal', 843),
#  ('filthstep', 828),
#  ('motown', 825),
#  ('outsider', 823),
#  ('canadianindie', 818),
#  ('focus', 817),
#  ('beatdown', 816),
#  ('nyhc', 812),
#  ('jazzguitar', 804),
#  ('balearic', 800),
#  ('dubtechno', 797),
#  ('raprock', 787),
#  ('afrobeat', 786),
#  ('hardstyle', 786),
#  ('midwestemo', 770),
#  ('pirate', 752),
#  ('bboy', 751),
#  ('punkblues', 745),
#  ('medievalfolk', 743),
#  ('sitar', 732),
#  ('hardcoretechno', 731),
#  ('dancehall', 730),
#  ('dronemetal', 696),
#  ('britishinvasion', 678),
#  ('folkpunk', 676),
#  ('darkjazz', 665),
#  ('indiepunk', 642),
#  ('accordion', 629),
#  ('experimentalambient', 629),
#  ('polishblackmetal', 623),
#  ('trancecore', 617),
#  ('filterhouse', 612),
#  ('neotango', 606),
#  ('acidtechno', 603),
#  ('football', 600),
#  ('funeraldoom', 597),
#  ('chanson', 595),
#  ('gothicdoom', 580),
#  ('samba', 577),
#  ('nordicfolk', 575),
#  ('mashup', 573),
#  ('cartoon', 567),
#  ('instrumentaldeathmetal', 563),
#  ('countryrock', 562),
#  ('orientalmetal', 553),
#  ('detroittechno', 550),
#  ('powerviolence', 549),
#  ('polishrock', 541),
#  ('celticpunk', 537),
#  ('rootsreggae', 535),
#  ('germanmetalcore', 530),
#  ('irishfolk', 524),
#  ('eurovision', 514),
#  ('noisepunk', 513),
#  ('cooljazz', 510),
#  ('vocaljazz', 503),
#  ('comedyrock', 501),
#  ('chillstep', 494),
#  ('streetpunk', 489),
#  ('hardhouse', 487),
#  ('tropical', 482),
#  ('finnishblackmetal', 481),
#  ('frenchmetal', 481),
#  ('geekrock', 480),
#  ('screamocore', 475),
#  ('latinjazz', 470),
#  ('bubblegumpop', 466),
#  ('oldschoolhiphop', 458),
#  ('brostep', 453),
#  ('ambientidm', 453),
#  ('electrotrash', 450),
#  ('folkpop', 441),
#  ('russianrock', 434),
#  ('salsa', 430),
#  ('nuskoolbreaks', 424),
#  ('electrodub', 418),
#  ('nugaze', 412),
#  ('harpsichord', 410),
#  ('mpb', 408),
#  ('psychedelicfolk', 406),
#  ('happyhardcore', 400),
#  ('ninja', 396),
#  ('gothicsymphonicmetal', 395),
#  ('westcoastrap', 392),
#  ('motivation', 389),
#  ('anarchopunk', 382),
#  ('throatsinging', 382),
#  ('drumfunk', 380),
#  ('easycore', 378),
#  ('electronicore', 376),
#  ('beachhouse', 366),
#  ('minimalwave', 361),
#  ('experimentalelectronic', 361),
#  ('polishjazz', 360),
#  ('polka', 359),
#  ('spaceambient', 357),
#  ('worship', 351),
#  ('brazilianrock', 349),
#  ('teenpop', 348),
#  ('electricblues', 342),
#  ('healing', 337),
#  ('nativeamerican', 331),
#  ('latinrock', 329),
#  ('doomcore', 326),
#  ('alternativecountry', 325),
#  ('germanhiphop', 317),
#  ('speedcore', 317),
#  ('klezmer', 316),
#  ('newbeat', 312),
#  ('avantgardejazz', 307),
#  ('etherealwave', 305),
#  ('neoprogressive', 304),
#  ('britishblues', 302),
#  ('brazilianmetal', 295),
#  ('deepfunk', 288),
#  ('celticrock', 287),
#  ('finnishfolk', 284),
#  ('disney', 283),
#  ('banjo', 282),
#  ('bagpipe', 281),
#  ('reggaefusion', 281),
#  ('blackthrash', 278),
#  ('gospel', 277),
#  ('swedishpop', 277),
#  ('italianmetal', 275),
#  ('flamenco', 274),
#  ('ukfunky', 273),
#  ('gypsypunk', 272),
#  ('exotica', 271),
#  ('tribalhouse', 268),
#  ('minimaltechhouse', 265),
#  ('drama', 264),
#  ('horrorcore', 261),
#  ('hollywood', 259),
#  ('mambo', 255),
#  ('eastcoasthiphop', 251),
#  ('harp', 249),
#  ('cabaret', 241),
#  ('medievalrock', 240),
#  ('highlife', 237),
#  ('rockenespanol', 227),
#  ('pubrock', 226),
#  ('rootsrock', 226),
#  ('greekblackmetal', 225),
#  ('jazzsaxophone', 223),
#  ('hamburgerschule', 223),
#  ('spanishindiepop', 218),
#  ('gogo', 216),
#  ('garagepop', 212),
#  ('rocknacional', 206),
#  ('reading', 206),
#  ('germanindie', 205),
#  ('retroelectro', 205),
#  ('rocksteady', 205),
#  ('nuelectro', 200),
#  ('bassmusic', 199),
#  ('calypso', 197),
#  ('germanblackmetal', 197),
#  ('bluegrass', 196),
#  ('moog', 196),
#  ('outlawcountry', 191),
#  ('greekmetal', 188),
#  ('tecnobrega', 186),
#  ('darktechno', 186),
#  ('cumbia', 184),
#  ('bebop', 183),
#  ('deepchill', 179),
#  ('vocaloid', 178),
#  ('frenchrock', 178),
#  ('norwegiandeathmetal', 175),
#  ('chillouttrance', 174),
#  ('bigband', 172),
#  ('theme', 170),
#  ('mantra', 170),
#  ('wrestling', 170),
#  ('australianmetal', 168),
#  ('jmetal', 166),
#  ('oldschoolthrash', 166),
#  ('melancholia', 165),
#  ('progressiveposthardcore', 164),
#  ('chillgroove', 164),
#  ('hurdygurdy', 161),
#  ('classicsoul', 160),
#  ('canadianrock', 159),
#  ('complextro', 157),
#  ('doowop', 157),
#  ('ukhiphop', 156),
#  ('hinrg', 154),
#  ('desi', 150),
#  ('rumba', 146),
#  ('polishpunk', 146),
#  ('ukrainianblackmetal', 145),
#  ('beachmusic', 145),
#  ('portuguesemetal', 144),
#  ('hardtechno', 144),
#  ('fingerstyle', 143),
#  ('chillbeats', 140),
#  ('deepambient', 139),
#  ('newjackswing', 139),
#  ('hungarianmetal', 137),
#  ('heartlandrock', 136),
#  ('nerdcore', 136),
#  ('danishmetal', 135),
#  ('drift', 133),
#  ('funkcarioca', 130),
#  ('psychedelicdoom', 128),
#  ('accordeon', 126),
#  ('musicbox', 125),
#  ('liedermacher', 125),
#  ('spanishrock', 123),
#  ('abstractbeats', 118),
#  ('latinpop', 118),
#  ('alternativehardcore', 117),
#  ('spanishpop', 117),
#  ('irishrock', 116),
#  ('karaoke', 115),
#  ('polishfolk', 115),
#  ('jumpstyle', 115),
#  ('neorockabilly', 114),
#  ('christianpop', 113),
#  ('handsup', 107),
#  ('terrorcore', 107),
#  ('latinalternative', 105),
#  ('russianalternative', 104),
#  ('technicalblackmetal', 103),
#  ('darkhardcore', 103),
#  ('conscioushiphop', 102),
#  ('metallichardcore', 101),
#  ('dungeonsynth', 101),
#  ('australianrock', 101),
#  ('austrianmetal', 100),
#  ('middleearth', 96),
#  ('contemporaryfolk', 96),
#  ('arabesk', 94),
#  ('bhangra', 94),
#  ('sufi', 92),
#  ('reggaerock', 92),
#  ('neopagan', 92),
#  ('benga', 88),
#  ('swedishhardcore', 88),
#  ('neuedeutschetodeskunst', 87),
#  ('praise', 87),
#  ('shibuyakei', 86),
#  ('antifolk', 86),
#  ('ambientindustrial', 86),
#  ('jazzorgan', 85),
#  ('texasblues', 85),
#  ('ambientfolk', 85),
#  ('cowpunk', 85),
#  ('popfolk', 83),
#  ('progressiveelectrohouse', 82),
#  ('fake', 82),
#  ('rockgaucho', 82),
#  ('ghettotech', 81),
#  ('neuedeutscheharte', 81),
#  ('footwork', 80),
#  ('renaissance', 78),
#  ('deepprogressivehouse', 78),
#  ('theremin', 77),
#  ('musiqueconcrete', 77),
#  ('intelligentdancemusic', 76),
#  ('gabba', 76),
#  ('irishmetal', 75),
#  ('retrosoul', 75),
#  ('melodichardrock', 74),
#  ('brassband', 73),
#  ('chicagohouse', 73),
#  ('didgeridoo', 72),
#  ('jazzrap', 70),
#  ('doujin', 70),
#  ('sunshinepop', 70),
#  ('magyar', 69),
#  ('swissmetal', 69),
#  ('jazztrumpet', 68),
#  ('bostonhardcore', 68),
#  ('crackrocksteady', 67),
#  ('organicambient', 66),
#  ('britishblackmetal', 64),
#  ('kuduro', 64),
#  ('russianindie', 63),
#  ('futurefunk', 62),
#  ('indieemo', 61),
#  ('balkanbrass', 61),
#  ('jpunk', 61),
#  ('japanoise', 60),
#  ('moombahton', 60),
#  ('rapconscient', 59),
#  ('poprap', 59),
#  ('pfunk', 59),
#  ('tribute', 58),
#  ('hauntology', 58),
#  ('futurerock', 57),
#  ('ccm', 56),
#  ('nasheed', 56),
#  ('retrometal', 53),
#  ('mariachi', 53),
#  ('raggajungle', 53),
#  ('blackdeath', 52),
#  ('neuedeutschewelle', 51),
#  ('tekno', 50),
#  ('blackenedcrust', 50),
#  ('freestyle', 49),
#  ('smoothsoul', 49),
#  ('neworleansfunk', 48),
#  ('canadianblackmetal', 46),
#  ('chicagoblues', 46),
#  ('hoerspiel', 46),
#  ('modernblues', 46),
#  ('riodelaplata', 45),
#  ('hardcorehiphop', 45),
#  ('darkpsytrance', 44),
#  ('vikingfolk', 44),
#  ('germanjazz', 44),
#  ('boogiewoogie', 44),
#  ('hardalternative', 44),
#  ('britishjazz', 44),
#  ('spaceagepop', 43),
#  ('christiandeathcore', 43),
#  ('vogue', 43),
#  ('irishindie', 43),
#  ('minimaldub', 43),
#  ('italianprogressiverock', 42),
#  ('germanpunk', 42),
#  ('germanpunkrock', 42),
#  ('tone', 42),
#  ('manguebit', 41),
#  ('melodicprogressivemetal', 41),
#  ('eurobeat', 40),
#  ('turkishrock', 40),
#  ('cajun', 39),
#  ('movietunes', 38),
#  ('classicalpiano', 38),
#  ('desertblues', 38),
#  ('jazztrio', 38),
#  ('redneck', 38),
#  ('hiphoptuga', 38),
#  ('australianhardcore', 37),
#  ('ranchera', 36),
#  ('fado', 36),
#  ('frenchblackmetal', 36),
#  ('russianmetal', 36),
#  ('russianpunk', 35),
#  ('ballroom', 34),
#  ('polishreggae', 34),
#  ('raregroove', 34),
#  ('stringquartet', 34),
#  ('northernsoul', 34),
#  ('soncubano', 33),
#  ('laboratorio', 33),
#  ('canterburyscene', 32),
#  ('indiepoprock', 32),
#  ('idol', 32),
#  ('dutchmetal', 32),
#  ('newagepiano', 31),
#  ('pixie', 30),
#  ('marchingband', 30),
#  ('jazzdrums', 30),
#  ('hardbop', 29),
#  ('latinfunk', 29),
#  ('darkblackmetal', 28),
#  ('frenchhiphop', 27),
#  ('gothicamericana', 26),
#  ('vaudeville', 26),
#  ('gypsyjazz', 26),
#  ('indianclassical', 26),
#  ('loversrock', 25),
#  ('norwegianjazz', 25),
#  ('minimaldubstep', 24),
#  ('deltablues', 24),
#  ('organicelectronic', 24),
#  ('afropop', 23),
#  ('worldchill', 23),
#  ('chiphop', 23),
#  ('sega', 23),
#  ('germanpop', 23),
#  ('deepprogressivetrance', 22),
#  ('polishmodernjazz', 21),
#  ('boombap', 21),
#  ('christianpunk', 20),
#  ('indieelectropop', 20),
#  ('mellowgold', 20),
#  ('germandance', 20),
#  ('spanishmetal', 20),
#  ('russianpop', 20),
#  ('italianblackmetal', 19),
#  ('ghoststep', 19),
#  ('dreamgaze', 19),
#  ('bemani', 19),
#  ('classicalguitar', 18),
#  ('turkishpop', 17),
#  ('boogaloo', 17),
#  ('deepdnb', 17),
#  ('gravewave', 17),
#  ('britishindierock', 17),
#  ('popchileno', 17),
#  ('soulblues', 16),
#  ('tibetan', 16),
#  ('chillhop', 16),
#  ('duduk', 16),
#  ('loungehouse', 16),
#  ('esperanto', 16),
#  ('germanreggae', 16),
#  ('yachtrock', 16),
#  ('latinmetal', 15),
#  ('belgianblackmetal', 15),
#  ('phillysoul', 15),
#  ('ukpop', 15),
#  ('christianhardrock', 15),
#  ('emopunk', 15),
#  ('demoscene', 15),
#  ('bolero', 15),
#  ('hammereddulcimer', 15),
#  ('pagode', 14),
#  ('dinnerjazz', 14),
#  ('cantautor', 13),
#  ('vaporwave', 13),
#  ('salsacubana', 13),
#  ('yeye', 13),
#  ('surfmusic', 13),
#  ('veganstraightedge', 13),
#  ('britishsoul', 13),
#  ('traditionalska', 13),
#  ('ringtone', 13),
#  ('acididm', 12),
#  ('quebecdeathmetal', 12),
#  ('germanelectronica', 12),
#  ('dronefolk', 12),
#  ('punkska', 12),
#  ('skarevival', 12),
#  ('welshrock', 12),
#  ('forestpsy', 12),
#  ('instrumentalfunk', 12),
#  ('skajazz', 11),
#  ('deeptechhouse', 11),
#  ('hardcorebreaks', 11),
#  ('oud', 10),
#  ('scandipop', 10),
#  ('estonianmetal', 10),
#  ('girlgroup', 10),
#  ('electrolatino', 10),
#  ('miamibass', 9),
#  ('ghazal', 8),
#  ('jazzviolin', 8),
#  ('indianjazz', 8),
#  ('psychedelicbluesrock', 8),
#  ('russianblackmetal', 8),
#  ('swedishpunk', 8),
#  ('brazilianexperimental', 8),
#  ('modrevival', 8),
#  ('steelguitar', 8),
#  ('cymraeg', 7),
#  ('dixieland', 7),
#  ('carnaval', 6),
#  ('jazzclarinet', 6),
#  ('romantico', 6),
#  ('polishelectronica', 6),
#  ('polishindie', 6),
#  ('swedishjazz', 6),
#  ('dutchhouse', 5),
#  ('bigroom', 5),
#  ('scottishindie', 4),
#  ('southernsoul', 4),
#  ('polyphony', 4),
#  ('braziliandeathmetal', 3),
#  ('belgianrock', 3),
#  ('swedishpostpunk', 3),
#  ('japaneseexperimental', 3),
#  ('recorder', 3),
#  ('lightmusic', 3),
#  ('bmore', 2),
#  ('trova', 2),
#  ('acousticblues', 2),
#  ('atmosphericpostrock', 1)]

# %%
genres_per_cluster_df.loc[2]["cluster"].values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-43ea08b9bd0f> in <module>
# ----> 1 genres_per_cluster_df.loc[2]["cluster"].values
#
# AttributeError: 'int' object has no attribute 'values'

# %%
genres_per_cluster_df.loc[3]["cluster"].values

# %%
genres_per_cluster_df.loc[4]["cluster"].values

# %%
n_tracks_df = events_df.merge(track_classification_df, left_on="track_id", right_index=True).groupby("cluster").size()
n_tracks_df
# Out:
# cluster
# 1     328962
# 2    2988736
# 3     171468
# 4     769203
# dtype: int64

# %%
# %matplotlib qt
c = 1
for count in genres_per_cluster_df.values:
    sorted_occs = sorted(dict(count).items(), key=lambda tup: tup[1])[::-1][:30]
    ys = list(zip(*sorted_occs))[1]
    ys = np.array(ys) / n_tracks_df.loc[c]
    plt.plot(list(range(30)), ys, "-o", label=r"$C_" + str(c) + "$")
    c += 1
plt.legend()
plt.ylabel("relative genre importance")
plt.xlabel("Top 30 genres")
plt.grid(False)
plt.show()

# %%
gradients = []
c = 1
for count in genres_per_cluster_df.values:
    sorted_occs = sorted(dict(count).items(), key=lambda tup: tup[1])[::-1][:10]
    ys = list(zip(*sorted_occs))[1]
    ys = np.array(ys) / n_tracks_df.loc[c]
    gradients.append(np.mean(np.gradient(ys)))
    c += 1

# %%
gradients
# Out:
# [-0.052009057867709506,
#  -0.010682634400516079,
#  -0.05582437942096445,
#  -0.01066137238341366]
